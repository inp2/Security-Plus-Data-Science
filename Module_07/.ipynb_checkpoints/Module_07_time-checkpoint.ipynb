# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

# %% [markdown]
# # Time-Series Analysis
#
# Time series is a series of data points indexed in time order. The data is organized by relatively deterministic timestamps and contains additional information we can extract.

# %% [markdown]
# ### Dataset Description
#
# Cybersecurity Breaches

# %%
df = pd.read_csv('data/Cyber Security Breaches.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Number                             Name_of_Covered_Entity  \
# 0           1       0                         Brooke Army Medical Center
# 1           2       1          Mid America Kidney Stone Association, LLC
# 2           3       2    Alaska Department of Health and Social Services
# 3           4       3  Health Services for Children with Special Need...
# 4           5       4                           L. Douglas Carlson, M.D.
#
#   State Business_Associate_Involved  Individuals_Affected Date_of_Breach  \
# 0    TX                         NaN                  1000     10/16/2009
# 1    MO                         NaN                  1000      9/22/2009
# 2    AK                         NaN                   501     10/12/2009
# 3    DC                         NaN                  3800      10/9/2009
# 4    CA                         NaN                  5257      9/27/2009
#
#   Type_of_Breach         Location_of_Breached_Information  \
# 0          Theft                                    Paper
# 1          Theft                           Network Server
# 2          Theft  Other Portable Electronic Device, Other
# 3           Loss                                   Laptop
# 4          Theft                         Desktop Computer
#
#   Date_Posted_or_Updated                                            Summary  \
# 0             2014-06-30  A binder containing the protected health infor...
# 1             2014-05-30  Five desktop computers containing unencrypted ...
# 2             2014-01-23                                                NaN
# 3             2014-01-23  A laptop was lost by an employee while in tran...
# 4             2014-01-23  A shared Computer that was used for backup was...
#
#   breach_start breach_end  year
# 0   2009-10-16        NaN  2009
# 1   2009-09-22        NaN  2009
# 2   2009-10-12        NaN  2009
# 3   2009-10-09        NaN  2009
# 4   2009-09-27        NaN  2009

# %% [markdown]
# Before we analyze our dataset let set if our time columns are actually time-series objects.

# %%
df.dtypes
# Out:
# Unnamed: 0                           int64
# Number                               int64
# Name_of_Covered_Entity              object
# State                               object
# Business_Associate_Involved         object
# Individuals_Affected                 int64
# Date_of_Breach                      object
# Type_of_Breach                      object
# Location_of_Breached_Information    object
# Date_Posted_or_Updated              object
# Summary                             object
# breach_start                        object
# breach_end                          object
# year                                 int64
# dtype: object

# %% [markdown]
# We can see `Date_of_Breach`, `Date_Posted_or_Updated`, `breach_start`, `breach_end`, and `year` all need to be converted to the `datetime` format.
#
# `datetime` is a module that supplies classes for manipulating dates and times in both simple and complex ways. `date` and `time` arithmetic is supported, the focus of the implementation is on efficient attribute extraction for output formatting and manipulation.
#
# Let's convert these columns to datetime format.

# %%
df['Date_of_Breach']
# Out:
# 0      10/16/2009
# 1       9/22/2009
# 2      10/12/2009
# 3       10/9/2009
# 4       9/27/2009
# 5       9/27/2009
# 6       9/27/2009
# 7       9/27/2009
# 8       9/27/2009
# 9       9/27/2009
# 10     10/20/2009
# 11     10/11/2009
# 12     11/12/2009
# 13     10/31/2009
# 14      12/8/2009
# 15     10/22/2009
# 16     11/26/2009
# 17      9/22/2009
# 18     12/11/2009
# 19     11/10/2009
# 20     10/26/2009
# 21      10/7/2009
# 22      12/1/2009
# 23      12/9/2009
# 24     12/15/2009
# 25     11/19/2009
# 26     11/19/2009
# 27      1/10/2010
# 28     11/24/2009
# 29      1/18/2010
#           ...
# 458    12/29/2011
# 459    12/29/2011
# 460      1/1/2012
# 461     1/11/2012
# 462     1/15/2012
# 463    12/31/2011
# 464    12/20/2011
# 465      1/9/2012
# 466     2/11/2012
# 467     1/11/2012
# 468     1/11/2012
# 469     1/12/2012
# 470     1/11/2012
# 471     2/25/2012
# 472     1/16/2012
# 473     1/11/2012
# 474     1/26/2012
# 475     1/11/2012
# 476     1/18/2012
# 477     1/26/2012
# 478    12/31/2011
# 479    01/17/2012
# 480    07/01/2008
# 481      2/2/2012
# 482     6/28/2011
# 483     1/27/2012
# 484     2/13/2012
# 485     3/16/2012
# 486      2/1/2012
# 487      2/7/2012
# Name: Date_of_Breach, Length: 488, dtype: object

# %%
df['Date_of_Breach'] = pd.to_datetime(df['Date_of_Breach'], format='%m/%d/%Y')
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# In order to plot with pandas the time must be the index of the dataframe.

# %%
df = df.set_index('Date_of_Breach')

# %%
df.head()
# Out:
#                 Unnamed: 0  Number  \
# Date_of_Breach
# 2009-10-16               1       0
# 2009-09-22               2       1
# 2009-10-12               3       2
# 2009-10-09               4       3
# 2009-09-27               5       4
#
#                                            Name_of_Covered_Entity State  \
# Date_of_Breach
# 2009-10-16                             Brooke Army Medical Center    TX
# 2009-09-22              Mid America Kidney Stone Association, LLC    MO
# 2009-10-12        Alaska Department of Health and Social Services    AK
# 2009-10-09      Health Services for Children with Special Need...    DC
# 2009-09-27                               L. Douglas Carlson, M.D.    CA
#
#                Business_Associate_Involved  Individuals_Affected  \
# Date_of_Breach
# 2009-10-16                             NaN                  1000
# 2009-09-22                             NaN                  1000
# 2009-10-12                             NaN                   501
# 2009-10-09                             NaN                  3800
# 2009-09-27                             NaN                  5257
#
#                Type_of_Breach         Location_of_Breached_Information  \
# Date_of_Breach
# 2009-10-16              Theft                                    Paper
# 2009-09-22              Theft                           Network Server
# 2009-10-12              Theft  Other Portable Electronic Device, Other
# 2009-10-09               Loss                                   Laptop
# 2009-09-27              Theft                         Desktop Computer
#
#                Date_Posted_or_Updated  \
# Date_of_Breach
# 2009-10-16                 2014-06-30
# 2009-09-22                 2014-05-30
# 2009-10-12                 2014-01-23
# 2009-10-09                 2014-01-23
# 2009-09-27                 2014-01-23
#
#                                                           Summary  \
# Date_of_Breach
# 2009-10-16      A binder containing the protected health infor...
# 2009-09-22      Five desktop computers containing unencrypted ...
# 2009-10-12                                                    NaN
# 2009-10-09      A laptop was lost by an employee while in tran...
# 2009-09-27      A shared Computer that was used for backup was...
#
#                breach_start breach_end  year
# Date_of_Breach
# 2009-10-16       2009-10-16        NaN  2009
# 2009-09-22       2009-09-22        NaN  2009
# 2009-10-12       2009-10-12        NaN  2009
# 2009-10-09       2009-10-09        NaN  2009
# 2009-09-27       2009-09-27        NaN  2009

# %% [markdown]
# Now, we can plot the volume over time.

# %%
df['Number'].resample('S').count().plot()

# %% [markdown]
# ### What is missing from the data? How can we deal with it?
#
# How do you predict/utilize/examine missing data? I don't know either. Let's first see if there is any missing data.

# %%
msno.matrix(df, figsize=(20,10))

# %% [markdown]
# The missingno library is a great quick way to quickly visually check fo rholes in a dataset, it detects where NaN values (or no values) appear and highlights them. White lines indicate missing values.
#
# It appears that `type`, `postalcode`, and `Unnamed: 15` have alot of missing values.
#
# What are your options when dealing with missing data?
#
# The quickest and easiet way would be to remove every row with missing values. Or remove the columns entirely.
#
# This can be a problem. Machine learning models like more data. Removing large amounts of data will likely decrease the capability of our model.

# %%
df.drop(columns=['type', 'postalcode', 'Unnamed: 15'])
# Out:
#             datetime               host         src proto      spt     dpt  \
# 0       3/3/13 21:53     groucho-oregon  1032051418   TCP   6000.0  1433.0
# 1       3/3/13 21:57     groucho-oregon  1347834426   UDP   5270.0  5060.0
# 2       3/3/13 21:58     groucho-oregon  2947856490   TCP   2489.0  1080.0
# 3       3/3/13 21:58    groucho-us-east   841842716   UDP  43235.0  1900.0
# 4       3/3/13 21:58  groucho-singapore  3587648279   TCP  56577.0    80.0
# 5       3/3/13 21:58      groucho-tokyo  3323217250   TCP  32628.0  2323.0
# 6       3/3/13 21:59     groucho-oregon  3730416887   TCP   6000.0  1433.0
# 7       3/3/13 22:07  groucho-singapore  3738622573   TCP   6000.0  3306.0
# 8       3/3/13 22:12     groucho-oregon  3683919430   TCP   6000.0  1433.0
# 9       3/3/13 22:14  groucho-singapore  1007884304   TCP   6000.0  1433.0
# 10      3/3/13 22:14      groucho-tokyo  3639889826   TCP   6000.0  1433.0
# 11      3/3/13 22:20     groucho-oregon  1965603898   TCP   9907.0  1433.0
# 12      3/3/13 22:20         groucho-sa  3672981807   TCP  33367.0    22.0
# 13      3/3/13 22:20       zeppo-norcal  3672981807   TCP  33367.0    22.0
# 14      3/3/13 22:19     groucho-norcal  3672981807   TCP  33367.0    22.0
# 15      3/3/13 22:20    groucho-us-east  3672981807   TCP  33367.0    22.0
# 16      3/3/13 22:21         groucho-eu  3672981807   TCP  33367.0    22.0
# 17      3/3/13 22:21     groucho-sydney  3672981807   TCP  33367.0    22.0
# 18      3/3/13 22:23     groucho-oregon  2382398543   TCP   6000.0  1433.0
# 19      3/3/13 22:26      groucho-tokyo  1965603898   TCP  26180.0  1433.0
# 20      3/3/13 22:29         groucho-eu  3683780686   UDP  54790.0  5060.0
# 21      3/3/13 22:29     groucho-oregon   840591020   TCP   2712.0    23.0
# 22      3/3/13 22:35     groucho-oregon  2945182618   TCP  48754.0    23.0
# 23      3/3/13 22:38      groucho-tokyo   621360428   TCP  45855.0  5900.0
# 24      3/3/13 22:40      groucho-tokyo  3305593070   TCP   3009.0   445.0
# 25      3/3/13 22:40      groucho-tokyo  3305593070   TCP   3009.0   445.0
# 26      3/3/13 22:41      groucho-tokyo  3019952728   TCP   3303.0   445.0
# 27      3/3/13 22:41      groucho-tokyo  3019952728   TCP   3303.0   445.0
# 28      3/3/13 22:42     groucho-oregon  1017977401   TCP   6000.0  1433.0
# 29      3/3/13 22:45     groucho-oregon  2917802434   TCP   6000.0  3306.0
# ...              ...                ...         ...   ...      ...     ...
# 451551   9/8/13 5:36      groucho-tokyo  3702236258   TCP   8888.0  1433.0
# 16             11   37.4906   127.0200
# 17             11   37.4906   127.0200
# 18             CA   37.3495  -122.1163
# 19             36   28.5500   115.9333
# 20             37   36.6683   116.9972
# 21             TX   35.1613  -101.8790
# 22             10    3.0833   101.6500
# 23            SPE   59.8944    30.2642
# 24            NaN   34.0000     9.0000
# 25            NaN   34.0000     9.0000
# 26             13   35.6850   139.7514
# 27             13   35.6850   139.7514
# 28             34   31.8639   117.2808
# 29             IL   41.8471   -87.6248
# ...           ...       ...        ...
# 451551         65   43.8010    87.6005
# 451552         65   43.8010    87.6005
# 451553         34   31.8639   117.2808
# 451554        NaN       NaN        NaN
# 451555        NaN   17.0500   -61.8000
# 451556        NaN   17.0500   -61.8000
# 451557         45   22.8167   108.3167
# 451558         21   41.7239   123.2017
# 451559        NaN   25.0392   121.5250
# 451560        NaN   25.0392   121.5250
# 451561         35   26.0614   119.3061
# 451562         ON   43.6525   -79.3686
# 451563        NaN   25.0392   121.5250
# 451564        NaN   25.0392   121.5250
# 451565         34   31.8639   117.2808
# 451566        NaN   35.0000   105.0000
# 451567         CO   39.6237  -104.8738
# 451568         44   23.1167   113.2500
# 451569        NaN   35.6900   139.6900
# 451570        NaN   35.6900   139.6900
# 451571         CO   40.4555  -105.4648
# 451572         CO   40.4555  -105.4648
# 451573         34   31.8639   117.2808
# 451574         13   35.6850   139.7514
# 451575         13   35.6850   139.7514
# 451576         13   35.6850   139.7514
# 451577         34   31.8639   117.2808
# 451578         CA   34.0530  -118.2642
# 451579        NaN   25.0392   121.5250
# 451580        NaN   25.0392   121.5250
#
# [451581 rows x 13 columns]

# %% [markdown]
# ## Outliers, where are they, and why you should pay attention to them?
#
# If you look at the number of occurrences of unique values within a dataset, one of the most common patterns is Zipf's law.
#
# <img src="images/Zipf.png">

# %% [markdown]
# Zipf's Law: The highest occuring variable will have double the number of occurrences of the second highest occurring variable, triple the amount of the third and so on.
#
# The definition of an outlier will be different for every dataset. As a general rule of thumb, you may consider anything more than 3 standard deviations away from the mean as an outlier.
#
# <img src="images/pot_outlier.png">

# %% [markdown]
# Another potential look at an outlier, is also shown below:
#
# <img src="images/pot_outlier2.png">
#
# Typically, you can find outliers based on distirbution, this may or may not be as true in security. Outliers does not mean there is an intrusion, but could provide necessary insight into the ongoings of a system. For a first pass of EDA, it is recommended you check what the distribution of each feature.

# %% [markdown]
# ### Exercise 3
#
# 1. Create three distribution plots of features for features of which you are interested?

# %% [markdown]
# Why should you worry about outliers?
#
# Keeping outliers in your dataset may turn out in your model overfitting (being too accurate, not general enough). Removing all the outliers may result in your model being too generalised (it doesn't do well on anything out of the ordinary). Best to experiment with this iteratively to find the best way to deal with outliers.

# %% [markdown]
# ## Getting more out of your data

# %% [markdown]
# Right now we have less than 15 features, but it is quite possible to have hundreds of features or too few features.
#
# After you started to:
# * Form an understanding
# * Got an idea of the distirbutions
# * Found some outliers and dealth with them
#
# Feature engineering can be broken down into categories: adding, removing, and changing.

# %% [markdown]
# Let us talk about removing a feature. It is pretty easy to see we have a couple of columns with duplicate information. `cc`, `country`, and `host` all provide us with some geographical information. We might choose not to remove `host` but we can remove either `cc` or `country`.

# %%
df.drop(columns=['cc'])
# Out:
#             datetime               host         src proto  type      spt  \
# 0       3/3/13 21:53     groucho-oregon  1032051418   TCP   NaN   6000.0
# 1       3/3/13 21:57     groucho-oregon  1347834426   UDP   NaN   5270.0
# 2       3/3/13 21:58     groucho-oregon  2947856490   TCP   NaN   2489.0
# 3       3/3/13 21:58    groucho-us-east   841842716   UDP   NaN  43235.0
# 4       3/3/13 21:58  groucho-singapore  3587648279   TCP   NaN  56577.0
# 5       3/3/13 21:58      groucho-tokyo  3323217250   TCP   NaN  32628.0
# 6       3/3/13 21:59     groucho-oregon  3730416887   TCP   NaN   6000.0
# 7       3/3/13 22:07  groucho-singapore  3738622573   TCP   NaN   6000.0
# 8       3/3/13 22:12     groucho-oregon  3683919430   TCP   NaN   6000.0
# 9       3/3/13 22:14  groucho-singapore  1007884304   TCP   NaN   6000.0
# 10      3/3/13 22:14      groucho-tokyo  3639889826   TCP   NaN   6000.0
# 11      3/3/13 22:20     groucho-oregon  1965603898   TCP   NaN   9907.0
# 12      3/3/13 22:20         groucho-sa  3672981807   TCP   NaN  33367.0
# 13      3/3/13 22:20       zeppo-norcal  3672981807   TCP   NaN  33367.0
# 14      3/3/13 22:19     groucho-norcal  3672981807   TCP   NaN  33367.0
# 15      3/3/13 22:20    groucho-us-east  3672981807   TCP   NaN  33367.0
# 16      3/3/13 22:21         groucho-eu  3672981807   TCP   NaN  33367.0
# 17      3/3/13 22:21     groucho-sydney  3672981807   TCP   NaN  33367.0
# 18      3/3/13 22:23     groucho-oregon  2382398543   TCP   NaN   6000.0
# 19      3/3/13 22:26      groucho-tokyo  1965603898   TCP   NaN  26180.0
# 20      3/3/13 22:29         groucho-eu  3683780686   UDP   NaN  54790.0
# 21      3/3/13 22:29     groucho-oregon   840591020   TCP   NaN   2712.0
# 22      3/3/13 22:35     groucho-oregon  2945182618   TCP   NaN  48754.0
# 23      3/3/13 22:38      groucho-tokyo   621360428   TCP   NaN  45855.0
# 24      3/3/13 22:40      groucho-tokyo  3305593070   TCP   NaN   3009.0
# 25      3/3/13 22:40      groucho-tokyo  3305593070   TCP   NaN   3009.0
# 26      3/3/13 22:41      groucho-tokyo  3019952728   TCP   NaN   3303.0
# 27      3/3/13 22:41      groucho-tokyo  3019952728   TCP   NaN   3303.0
# 28      3/3/13 22:42     groucho-oregon  1017977401   TCP   NaN   6000.0
# 29      3/3/13 22:45     groucho-oregon  2917802434   TCP   NaN   6000.0
# ...              ...                ...         ...   ...   ...      ...
# 451551   9/8/13 5:36      groucho-tokyo  3702236258   TCP   NaN   8888.0
# 451552   9/8/13 5:36      groucho-tokyo  3702236258   TCP   NaN   8888.0
# 451553   9/8/13 5:35         groucho-eu  1017974360   TCP   NaN   6000.0
# 451554   9/8/13 5:36         groucho-eu   170932385   UDP   NaN     67.0
# 451555   9/8/13 5:41      groucho-tokyo  1161424878   TCP   NaN  55494.0
# 451556   9/8/13 5:41      groucho-tokyo  1161424878   TCP   NaN  55494.0
# 26       445.0     180.0.210.88                Japan
# 27       445.0     180.0.210.88                Japan
# 28      1433.0     60.173.26.57                China
# 29      3306.0   173.234.33.194        United States
# ...        ...              ...                  ...
# 451551  1433.0   220.171.164.98                China
# 451552  8080.0   220.171.164.98                China
# 451553  8090.0     60.173.14.88                China
# 451554    68.0     10.48.56.161                  NaN
# 451555   445.0    69.57.239.238  Antigua and Barbuda
# 451556   445.0    69.57.239.238  Antigua and Barbuda
# 451557  1433.0   171.111.158.69                China
# 451558    22.0  219.235.126.174                China
# 451559   445.0    118.232.4.245               Taiwan
# 451560   445.0    118.232.4.245               Taiwan
# 451561  1433.0    125.77.197.44                China
# 451562     NaN   192.186.147.89               Canada
# 451563   445.0  118.233.142.122               Taiwan
# 451564   445.0  118.233.142.122               Taiwan
# 451565  8090.0     60.173.14.88                China
# 451566  1433.0   203.156.217.61                China
# 451567    53.0     204.42.253.2        United States
# 451568  1433.0   119.147.102.22                China
# 451569   445.0   219.97.157.165                Japan
# 451570   445.0   219.97.157.165                Japan
# 451571     NaN    129.82.138.44        United States
# 451572     NaN    129.82.138.44        United States
# 451573  1433.0   114.101.65.121                China
# 451574   445.0   114.158.78.173                Japan
# 451575   445.0   114.158.78.173                Japan
# 451576   445.0   114.158.78.173                Japan
# 451577  8090.0     60.173.14.88                China
# 451578  1433.0  192.200.102.171        United States
# 451579   445.0    1.173.108.132               Taiwan
# 451580   445.0    1.173.108.132               Taiwan
#
#                           locale localeabbr postalcode  latitude  longitude  \
# 0                  Jiangxi Sheng         36        NaN   28.5500   115.9333
# 1                            NaN        NaN        NaN   51.0000     9.0000
# 2                         Taipei        NaN        NaN   25.0392   121.5250
# 3                         Oregon         OR      97124   45.5848  -122.9117
# 4                            NaN        NaN        NaN   48.8600     2.3500
# 5                       Illinois         IL      60661   41.8825   -87.6441
# 6                    Henan Sheng         41        NaN   34.6836   113.5325
# 7                  Sichuan Sheng         51        NaN   30.6667   104.0667
# 8                          Hebei         13        NaN   39.8897   115.2750
# 9                       Liaoning         21        NaN   41.7922   123.4328
# 10                    Washington         WA      98168   47.4891  -122.2908
# 11                 Jiangxi Sheng         36        NaN   28.5500   115.9333
# 12                         Seoul         11        NaN   37.4906   127.0200
# 13                         Seoul         11        NaN   37.4906   127.0200
# 14                         Seoul         11        NaN   37.4906   127.0200
# 15                         Seoul         11        NaN   37.4906   127.0200
# 16                         Seoul         11        NaN   37.4906   127.0200
# 17                         Seoul         11        NaN   37.4906   127.0200
# 18                    California         CA      94024   37.3495  -122.1163
# 19                 Jiangxi Sheng         36        NaN   28.5500   115.9333
# 20                Shandong Sheng         37        NaN   36.6683   116.9972
# 21                         Texas         TX      79109   35.1613  -101.8790
# 22                      Selangor         10        NaN    3.0833   101.6500
# 23                St.-Petersburg        SPE        NaN   59.8944    30.2642
# 24                           NaN        NaN        NaN   34.0000     9.0000
# 25                           NaN        NaN        NaN   34.0000     9.0000
# 26                      Tokyo-to         13        NaN   35.6850   139.7514
# 27                      Tokyo-to         13        NaN   35.6850   139.7514
# 28                   Anhui Sheng         34        NaN   31.8639   117.2808
# 29                      Illinois         IL      60616   41.8471   -87.6248
# ...                          ...        ...        ...       ...        ...
# 451551    Xinjiang Uygur Zizhiqu         65        NaN   43.8010    87.6005
# 451552    Xinjiang Uygur Zizhiqu         65        NaN   43.8010    87.6005
# 451553               Anhui Sheng         34        NaN   31.8639   117.2808
# 451554                       NaN        NaN        NaN       NaN        NaN
# 451555                       NaN        NaN        NaN   17.0500   -61.8000
# 451556                       NaN        NaN        NaN   17.0500   -61.8000
# 451557  Guangxi Zhuangzu Zizhiqu         45        NaN   22.8167   108.3167
# 451558                  Liaoning         21        NaN   41.7239   123.2017
# 451559                    Taipei        NaN        NaN   25.0392   121.5250
# 451560                    Taipei        NaN        NaN   25.0392   121.5250
# 451561                    Fujian         35        NaN   26.0614   119.3061
# 451562                   Ontario         ON        M5V   43.6525   -79.3686
# 451563                    Taipei        NaN        NaN   25.0392   121.5250
# 451564                    Taipei        NaN        NaN   25.0392   121.5250
# 451565               Anhui Sheng         34        NaN   31.8639   117.2808
# 451566                       NaN        NaN        NaN   35.0000   105.0000
# 451567                  Colorado         CO      80111   39.6237  -104.8738
# 451568                 Guangdong         44        NaN   23.1167   113.2500
# 451569                       NaN        NaN        NaN   35.6900   139.6900
# 451570                       NaN        NaN        NaN   35.6900   139.6900
# 451571                  Colorado         CO      80523   40.4555  -105.4648
# 451572                  Colorado         CO      80523   40.4555  -105.4648
# 451573               Anhui Sheng         34        NaN   31.8639   117.2808
# 451574                  Tokyo-to         13        NaN   35.6850   139.7514
# 451575                  Tokyo-to         13        NaN   35.6850   139.7514
# 451576                  Tokyo-to         13        NaN   35.6850   139.7514
# 451577               Anhui Sheng         34        NaN   31.8639   117.2808
# 451578                California         CA      90017   34.0530  -118.2642
# 451579                    Taipei        NaN        NaN   25.0392   121.5250
# 451580                    Taipei        NaN        NaN   25.0392   121.5250
#
#         Unnamed: 15
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 451551          NaN
# 451552          NaN
# 451553          NaN
# 451554          NaN
# 451555          NaN
# 451556          NaN
# 451557          NaN
# 451558          NaN
# 451559          NaN
# 451560          NaN
# 451561          NaN
# 451562          NaN
# 451563          NaN
# 451564          NaN
# 451565          NaN
# 451566          NaN
# 451567          NaN
# 451568          NaN
# 451569          NaN
# 451570          NaN
# 451571          NaN
# 451572          NaN
# 451573          NaN
# 451574          NaN
# 451575          NaN
# 451576          NaN
# 451577          NaN
# 451578          NaN
# 451579          NaN
# 451580          NaN
#
# [451581 rows x 15 columns]

# %% [markdown]
# The same can be said for `locale` and `localeabbr`.

# %%
df.drop(columns=['localeabbr'])
# Out:
#             datetime               host         src proto  type      spt  \
# 0       3/3/13 21:53     groucho-oregon  1032051418   TCP   NaN   6000.0
# 1       3/3/13 21:57     groucho-oregon  1347834426   UDP   NaN   5270.0
# 2       3/3/13 21:58     groucho-oregon  2947856490   TCP   NaN   2489.0
# 3       3/3/13 21:58    groucho-us-east   841842716   UDP   NaN  43235.0
# 4       3/3/13 21:58  groucho-singapore  3587648279   TCP   NaN  56577.0
# 451556   445.0    69.57.239.238   AG  Antigua and Barbuda
# 451557  1433.0   171.111.158.69   CN                China
# 451558    22.0  219.235.126.174   CN                China
# 451559   445.0    118.232.4.245   TW               Taiwan
# 451560   445.0    118.232.4.245   TW               Taiwan
# 451561  1433.0    125.77.197.44   CN                China
# 451562     NaN   192.186.147.89   CA               Canada
# 451563   445.0  118.233.142.122   TW               Taiwan
# 451564   445.0  118.233.142.122   TW               Taiwan
# 451565  8090.0     60.173.14.88   CN                China
# 451566  1433.0   203.156.217.61   CN                China
# 451567    53.0     204.42.253.2   US        United States
# 451568  1433.0   119.147.102.22   CN                China
# 451569   445.0   219.97.157.165   JP                Japan
# 451570   445.0   219.97.157.165   JP                Japan
# 451571     NaN    129.82.138.44   US        United States
# 451572     NaN    129.82.138.44   US        United States
# 451573  1433.0   114.101.65.121   CN                China
# 451574   445.0   114.158.78.173   JP                Japan
# 451575   445.0   114.158.78.173   JP                Japan
# 451576   445.0   114.158.78.173   JP                Japan
# 451577  8090.0     60.173.14.88   CN                China
# 451578  1433.0  192.200.102.171   US        United States
# 451579   445.0    1.173.108.132   TW               Taiwan
# 451580   445.0    1.173.108.132   TW               Taiwan
#
#                           locale postalcode  latitude  longitude  Unnamed: 15
# 0                  Jiangxi Sheng        NaN   28.5500   115.9333          NaN
# 1                            NaN        NaN   51.0000     9.0000          NaN
# 2                         Taipei        NaN   25.0392   121.5250          NaN
# 3                         Oregon      97124   45.5848  -122.9117          NaN
# 4                            NaN        NaN   48.8600     2.3500          NaN
# 5                       Illinois      60661   41.8825   -87.6441          NaN
# 6                    Henan Sheng        NaN   34.6836   113.5325          NaN
# 7                  Sichuan Sheng        NaN   30.6667   104.0667          NaN
# 8                          Hebei        NaN   39.8897   115.2750          NaN
# 9                       Liaoning        NaN   41.7922   123.4328          NaN
# 10                    Washington      98168   47.4891  -122.2908          NaN
# 11                 Jiangxi Sheng        NaN   28.5500   115.9333          NaN
# 12                         Seoul        NaN   37.4906   127.0200          NaN
# 13                         Seoul        NaN   37.4906   127.0200          NaN
# 14                         Seoul        NaN   37.4906   127.0200          NaN
# 15                         Seoul        NaN   37.4906   127.0200          NaN
# 16                         Seoul        NaN   37.4906   127.0200          NaN
# 17                         Seoul        NaN   37.4906   127.0200          NaN
# 18                    California      94024   37.3495  -122.1163          NaN
# 19                 Jiangxi Sheng        NaN   28.5500   115.9333          NaN
# 20                Shandong Sheng        NaN   36.6683   116.9972          NaN
# 21                         Texas      79109   35.1613  -101.8790          NaN
# 22                      Selangor        NaN    3.0833   101.6500          NaN
# 23                St.-Petersburg        NaN   59.8944    30.2642          NaN
# 24                           NaN        NaN   34.0000     9.0000          NaN
# 25                           NaN        NaN   34.0000     9.0000          NaN
# 26                      Tokyo-to        NaN   35.6850   139.7514          NaN
# 27                      Tokyo-to        NaN   35.6850   139.7514          NaN
# 28                   Anhui Sheng        NaN   31.8639   117.2808          NaN
# 29                      Illinois      60616   41.8471   -87.6248          NaN
# ...                          ...        ...       ...        ...          ...
# 451551    Xinjiang Uygur Zizhiqu        NaN   43.8010    87.6005          NaN
# 451552    Xinjiang Uygur Zizhiqu        NaN   43.8010    87.6005          NaN
# 451553               Anhui Sheng        NaN   31.8639   117.2808          NaN
# 451554                       NaN        NaN       NaN        NaN          NaN
# 451555                       NaN        NaN   17.0500   -61.8000          NaN
# 451556                       NaN        NaN   17.0500   -61.8000          NaN
# 451557  Guangxi Zhuangzu Zizhiqu        NaN   22.8167   108.3167          NaN
# 451558                  Liaoning        NaN   41.7239   123.2017          NaN
# 451559                    Taipei        NaN   25.0392   121.5250          NaN
# 451560                    Taipei        NaN   25.0392   121.5250          NaN
# 451561                    Fujian        NaN   26.0614   119.3061          NaN
# 451562                   Ontario        M5V   43.6525   -79.3686          NaN
# 451563                    Taipei        NaN   25.0392   121.5250          NaN
# 451564                    Taipei        NaN   25.0392   121.5250          NaN
# 451565               Anhui Sheng        NaN   31.8639   117.2808          NaN
# 451566                       NaN        NaN   35.0000   105.0000          NaN
# 451567                  Colorado      80111   39.6237  -104.8738          NaN
# 451568                 Guangdong        NaN   23.1167   113.2500          NaN
# 451569                       NaN        NaN   35.6900   139.6900          NaN
# 451570                       NaN        NaN   35.6900   139.6900          NaN
# 451571                  Colorado      80523   40.4555  -105.4648          NaN
# 451572                  Colorado      80523   40.4555  -105.4648          NaN
# 451573               Anhui Sheng        NaN   31.8639   117.2808          NaN
# 451574                  Tokyo-to        NaN   35.6850   139.7514          NaN
# 451575                  Tokyo-to        NaN   35.6850   139.7514          NaN
# 451576                  Tokyo-to        NaN   35.6850   139.7514          NaN
# 451577               Anhui Sheng        NaN   31.8639   117.2808          NaN
# 451578                California      90017   34.0530  -118.2642          NaN
# 451579                    Taipei        NaN   25.0392   121.5250          NaN
# 451580                    Taipei        NaN   25.0392   121.5250          NaN
#
# [451581 rows x 15 columns]

# %% [markdown]
# Now, lets decide from our research that the ASN (Autonomous System Number) description information. We can create a new feature and add this to our dataset.

# %%
for index, row in df.iterrows():
    try:
        obj = IPWhois(row['srcstr'])
        res = obj.lookup_whois()
        row['ASN'] = res['asn_description']
    except:
        row['ASN'] = " "

# %%
df['ASN']

# %% [markdown]
# ### Exercise 4
#
# * Take some time and familiarize yourself with this dataset
# * Create/remove/change a feature you believe would be important to this dataset

# %% [markdown]
# ### Feature Contribution
#
# Feature contribution is a method of figuring out how much each feature influences a model. Knowing how much a feture contirbutes to a model can give you direction as to where to go next with your feature engineering.
#
# <img src="images/zip_feat.png">
#
# Removing features reduces the dimensionality of your data. It mean syour model has fewer connections to make to figure out the best wya of fitting the data. You might find rmeoving features means your model can get the same (or better) results on fewer data and in less time.

# %% [markdown]
# This is where we would begin to build our first model, before we get into models we will explore more concepts of looking a data (i.e. graph-based and time-series based.

# %% [markdown]
# References:
# 1. https://towardsdatascience.com/hitchhikers-guide-to-exploratory-data-analysis-6e8d896d3f7e
# 2. https://towardsdatascience.com/a-gentle-introduction-to-exploratory-data-analysis-f11d843b8184
# 3. https://github.com/ritikabhasker/Intro-to-EDA/blob/master/Intro_to_EDA.ipynb
