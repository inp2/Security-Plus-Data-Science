# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

df = pd.read_csv('data/Cyber Security Breaches.csv')

# %% [markdown]
# # Exercise 1
#
# * Choose any one of the time-series columns
# * Plot the number of events over time

# %%
df['breach_end'] = pd.to_datetime(df['breach_end'], format='%Y-%m-%d')
df = df.set_index('breach_end')
df['Number'].resample('M').count().plot()

# %% [markdown]
# ### Exercise 3
#
# 1. Create three distribution plots of features for features of which you are interested?

# %%
df.src.value_counts().plot.hist()

# %%
df.proto.value_counts().plot.hist()

# %%
df.country.value_counts().plot.hist()

# %% [markdown]
# ### Exercise 4
#
# * Take some time and familiarize yourself with this dataset
# * Create/remove/change a feature you believe would be important to this dataset

# %%
# I decided to convert port column from float to integer
df = df.fillna(0)
df['spt'] = df['spt'].astype(int)
df['spt']
# Out:
# 0          6000
# 1          5270
# 2          2489
# 3         43235
# 4         56577
# 5         32628
# 6          6000
# 7          6000
# 8          6000
# 9          6000
# 10         6000
# 11         9907
# 12        33367
# 13        33367
# 14        33367
# 15        33367
# 16        33367
# 17        33367
# 18         6000
# 19        26180
# 20        54790
# 21         2712
# 22        48754
# 23        45855
# 24         3009
# 25         3009
# 26         3303
# 27         3303
# 28         6000
# 29         6000
#           ...
# 451551     8888
# 451552     8888
# 451553     6000
# 451554       67
# 451555    55494
# 451556    55494
# 451557     6000
# 451558    11057
# 451559     2706
# 451560     2706
# 451561     6000
# 451562        0
# 451563     4130
# 451564     4130
# 451565     6000
# 451566    62125
# 451567    40707
# 451568     6000
# 451569     2439
# 451570     2439
# 451571        0
# 451572        0
# 451573     6000
# 451574    62175
# 451575    62175
# 451576    62175
# 451577     6000
# 451578     6000
# 451579     3555
# 451580     3555
# Name: spt, Length: 451581, dtype: int64
